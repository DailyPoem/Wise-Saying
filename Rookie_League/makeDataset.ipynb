# %% [markdown]
# # 통합 데이터셋 구축

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 팀투수 데이터셋

# %%
cd drive/Othercomputers/내 노트북/googleDrive/Bigcontest/Rookie_League/01_제공데이터/팀투수

# %%
pitcher_team_2016 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_팀투수_2016.csv')
pitcher_team_2017 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_팀투수_2017.csv')
pitcher_team_2018 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_팀투수_2018.csv')
pitcher_team_2019 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_팀투수_2019.csv')
pitcher_team_2020 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_팀투수_2020.csv')
pitcher_team_2021 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_팀투수_2021.csv')

# %%
pitcher_team = pd.concat([pitcher_team_2016, pitcher_team_2017, pitcher_team_2018, pitcher_team_2019, pitcher_team_2020, pitcher_team_2021], ignore_index=True)
pitcher_team
# Out:
#                G_ID   GDAY_DS T_ID  ... P_WHIP_RT  P2_WHIP_RT CB_WHIP_RT
# 0     20160401HHLG0  20160401   LG  ...  0.642857         0.0   2.400000
# 1     20160401HHLG0  20160401   HH  ...  1.500000         0.0   0.750000
# 2     20160401HTNC0  20160401   NC  ...  1.333333         0.0   2.142857
# 3     20160401HTNC0  20160401   HT  ...  0.500000         0.0   1.875000
# 4     20160401KTSK0  20160401   SK  ...  1.000000         0.0   2.250000
# ...             ...       ...  ...  ...       ...         ...        ...
# 7963  20210711HHSK0  20210711   HH  ...  1.363636         0.0   1.500000
# 7964  20210711KTHT0  20210711   HT  ...  0.600000         0.0   0.250000
# 7965  20210711KTHT0  20210711   KT  ...  1.500000         0.0   0.333333
# 7966  20210711LTSS0  20210711   LT  ...  2.142857         0.0   1.666667
# 7967  20210711LTSS0  20210711   SS  ...  0.375000         0.0   0.900000
#
# [7968 rows x 35 columns]

# %%
cd ../팀타자
# Out:
# /content/drive/Othercomputers/내 노트북/googleDrive/BigContest/Rookie_League/01_제공데이터/팀타자

# %%
hitter_team_2016 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2016.csv')
hitter_team_2017 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2017.csv')
hitter_team_2018 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2018.csv')
hitter_team_2019 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2019.csv')
hitter_team_2020 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2020.csv')
hitter_team_2021 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2021.csv')

# %%
hitter_team = pd.concat([hitter_team_2016, hitter_team_2017, hitter_team_2018, hitter_team_2019, hitter_team_2020, hitter_team_2021], ignore_index=True)
hitter_team
# Out:
#                G_ID   GDAY_DS T_ID VS_T_ID  ...  LOB  P_HRA_RT  P_AB_CN  P_HIT_CN
# 0     20160401HHLG0  20160401   HH      LG  ...   12  0.200000       15         3
# 1     20160401HHLG0  20160401   LG      HH  ...    8  0.333333       12         4
# 2     20160401HTNC0  20160401   HT      NC  ...    7  0.100000       10         1
# 3     20160401HTNC0  20160401   NC      HT  ...    7  0.142857        7         1
# 4     20160401KTSK0  20160401   SK      KT  ...    5  0.375000        8         3
# ...             ...       ...  ...     ...  ...  ...       ...      ...       ...
# 7963  20210711HHSK0  20210711   HH      SK  ...    2  0.000000        1         0
# 7964  20210711KTHT0  20210711   KT      HT  ...    7  0.000000        5         0
# 7965  20210711KTHT0  20210711   HT      KT  ...    5  0.200000        5         1
# 7966  20210711LTSS0  20210711   LT      SS  ...    7  0.000000        7         0
# ...

# %%
cd ../개인타자
# Out:
# /content/drive/Othercomputers/내 노트북/googleDrive/BigContest/Rookie_League/01_제공데이터/개인타자

# %%
hitter_2016 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_개인타자_2016.csv')
hitter_2017 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_개인타자_2017.csv')
hitter_2018 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_개인타자_2018.csv')
hitter_2019 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_개인타자_2019.csv')
hitter_2020 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_개인타자_2020.csv')
hitter_2021 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_개인타자_2021.csv')

# %%
hitter = pd.concat([hitter_2016, hitter_2017, hitter_2018, hitter_2019, hitter_2020, hitter_2021],ignore_index=True)
hitter
# Out:
#                  G_ID   GDAY_DS T_ID VS_T_ID  ...  LOB P_HRA_RT  P_AB_CN  P_HIT_CN
# 0       20160401HHLG0  20160401   HH      LG  ...    1      0.0        0         0
# 1       20160401HHLG0  20160401   LG      HH  ...    0      0.0        0         0
# 2       20160401HHLG0  20160401   LG      HH  ...    0      1.0        1         1
# 3       20160401HHLG0  20160401   LG      HH  ...    0      0.0        0         0
# 4       20160401HHLG0  20160401   HH      LG  ...    0      0.0        0         0
# ...               ...       ...  ...     ...  ...  ...      ...      ...       ...
# 101338  20210711LTSS0  20210711   SS      LT  ...    0      0.0        2         0
# 101339  20210711LTSS0  20210711   SS      LT  ...    0      0.0        0         0
# 101340  20210711LTSS0  20210711   LT      SS  ...    1      0.0        1         0
# 101341  20210711LTSS0  20210711   LT      SS  ...    0      0.0        1         0
# ...

# %%
cd ../개인투수
# Out:
# /content/drive/Othercomputers/내 노트북/googleDrive/BigContest/Rookie_League/01_제공데이터/개인투수

# %%
pitcher_2016 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_개인투수_2016.csv')
pitcher_2017 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_개인투수_2017.csv')
pitcher_2018 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_개인투수_2018.csv')
pitcher_2019 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_개인투수_2019.csv')
pitcher_2020 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_개인투수_2020.csv')
pitcher_2021 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_개인투수_2021.csv')

# %%
pitcher = pd.concat([pitcher_2016, pitcher_2017, pitcher_2018, pitcher_2019, pitcher_2020, pitcher_2021], ignore_index=True)
pitcher
# Out:
#                 G_ID   GDAY_DS T_ID  ... P_WHIP_RT  P2_WHIP_RT CB_WHIP_RT
# 0      20160401HHLG0  20160401   LG  ...  0.000000    1.000000   1.500000
# 1      20160401HHLG0  20160401   LG  ...  0.000000    1.800000   1.500000
# 2      20160401HHLG0  20160401   LG  ...  0.000000    3.000000   0.000000
# 3      20160401HHLG0  20160401   LG  ...  0.818182    1.588235   3.750000
# 4      20160401HHLG0  20160401   HH  ...  0.000000    1.500000   0.000000
# ...              ...       ...  ...  ...       ...         ...        ...
# 35323  20210711LTSS0  20210711   SS  ...  0.000000    0.000000   0.000000
# 35324  20210711LTSS0  20210711   LT  ...  0.000000    0.000000   0.000000
# 35325  20210711LTSS0  20210711   SS  ...  0.000000    1.000000   0.333333
# 35326  20210711LTSS0  20210711   SS  ...  1.000000    0.000000   0.000000
# 35327  20210711LTSS0  20210711   LT  ...  0.000000    0.000000   0.000000
#
# [35328 rows x 38 columns]

# %%
cd ../선수
# Out:
# /content/drive/Othercomputers/내 노트북/googleDrive/BigContest/Rookie_League/01_제공데이터/선수

# %%
player_2016 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_선수_2016.csv', encoding='cp949')
player_2017 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_선수_2017.csv', encoding='cp949')
player_2018 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_선수_2018.csv', encoding='cp949')
player_2019 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_선수_2019.csv', encoding='cp949')
player_2020 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_선수_2020.csv', encoding='cp949')
player_2021 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_선수_2021.csv', encoding='cp949')

# %%
player = pd.concat([player_2016, player_2017, player_2018, player_2019, player_2020, player_2021], ignore_index=True)
player
# Out:
#       GYEAR  PCODE NAME T_ID POSITION  AGE_VA    MONEY
# 0      2016  60100  백창수   LG        내      28   4000만원
# 1      2016  60105  배민관   LG        투      24   2700만원
# 2      2016  60146  이승현   LG        투      24   3700만원
# 3      2016  60164  유경국   LG        투      24   2700만원
# 4      2016  60181  김지용   LG        투      28   4000만원
# ...     ...    ...  ...  ...      ...     ...      ...
# 3969   2021  79456  이지영   WO        포      35  30000만원
# 3970   2021  79545  진명호   LT        투      32   7500만원
# 3971   2021  79608  안치홍   LT        내      31  29000만원
# 3972   2021  79764  장민재   HH        투      31  10000만원
# 3973   2021  79847  김태훈   SK        투      31  16000만원
#
# [3974 rows x 7 columns]

# %%
player.to_csv('선수_데이터셋.csv', index=False)
pitcher.to_csv('개인투수_데이터셋.csv', index=False)
hitter.to_csv('개인타자_데이터셋.csv', index=False)
pitcher_team.to_csv('팀투수_데이터셋.csv', index=False)
hitter_team.to_csv('팀타자_데이터셋.csv', index=False)
