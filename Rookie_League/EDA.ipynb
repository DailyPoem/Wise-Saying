# %% [markdown]
# # 구글 클라우드 데이터 폴더로 이동

# %%
cd drive/Othercomputers/내 노트북/googleDrive/BigContest/Rookie_League/01_제공데이터
# Out:
# /content/drive/Othercomputers/내 노트북/googleDrive/BigContest/Rookie_League/01_제공데이터

# %%
cd 팀타자/
# Out:
# /content/drive/Othercomputers/내 노트북/googleDrive/BigContest/Rookie_League/01_제공데이터/팀타자

# %%
ls
# Out:
# '2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2016.csv'
# '2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2017.csv'
# '2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2018.csv'
# '2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2019.csv'
# '2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2020.csv'
# '2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2021.csv'

# %% [markdown]
# # 데이터 EDA
# 개인 선수와 팀 데이터의 차이점 분석

# %% [markdown]
# ## 데이터 불러오기

# %%
import pandas as pd

df_2016 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2016.csv')
df_2017 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2017.csv')
df_2018 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2018.csv')
df_2019 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2019.csv')
df_2020 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2020.csv')
df_2021 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2021.csv')
df_2021.head()
# Out:
#             G_ID   GDAY_DS T_ID VS_T_ID  ...  LOB  P_HRA_RT  P_AB_CN  P_HIT_CN
# 0  20210403SSWO0  20210403   WO      SS  ...    6  0.222222        9         2
# 1  20210403SSWO0  20210403   SS      WO  ...    4  0.250000        4         1
# 2  20210404HHKT0  20210404   HH      KT  ...    9  0.200000       10         2
# 3  20210404HHKT0  20210404   KT      HH  ...    6  0.250000        4         1
# 4  20210404HTOB0  20210404   HT      OB  ...    9  0.166667        6         1
#
# [5 rows x 28 columns]

# %% [markdown]
# ## 팀 별로 데이터 나누기

# %%
# 탐 타자 팀별로 구분
WO = pd.DataFrame()
SS = pd.DataFrame()
SK = pd.DataFrame()
NC = pd.DataFrame()
HT = pd.DataFrame()
KT = pd.DataFrame()
HH = pd.DataFrame()
LG = pd.DataFrame()
LT = pd.DataFrame()
def split_team(Tname):
    WO = df_2016['T_ID'] == Tname
    df = df_2016[WO]

    WO = df_2017['T_ID'] == Tname
    dfsec2 = df_2017[WO]
    df = pd.concat([df, dfsec2])

    WO = df_2018['T_ID'] == Tname
    dfsec2 = df_2018[WO]
    df = pd.concat([df, dfsec2])

    WO = df_2019['T_ID'] == Tname
    dfsec2 = df_2019[WO]
    df = pd.concat([df, dfsec2])

    WO = df_2020['T_ID'] == Tname
    dfsec2 = df_2020[WO]
    df = pd.concat([df, dfsec2])

    WO = df_2021['T_ID'] == Tname
    dfsec2 = df_2021[WO]
    df = pd.concat([df, dfsec2])
    return df
WO = split_team('WO')
SS = split_team('SS')
OB = split_team('OB')
SK = split_team('SK')
NC = split_team('NC')
HT = split_team('HT')
KT = split_team('KT')
HH = split_team('HH')
LG = split_team('LG')
LT = split_team('LT')

# %% [markdown]
# ### 팀 타자 feature 정리
# * G_ID : 게임키(경기 구분 코드 값)
# * GDAY_DS : 일자(경기 일)
# * T_ID : 팀코드
# * VS_T_ID : 상대팀 코드
# * HEADER_NO : 더블 헤더 코드(경기 더블 헤더 구분 값)
# * TB_SC : 초말(이닝 초/말 구분 값)
# * PA : 타석
# * AB : 타수(총 타수)
# * RBI : 타점
# * RUN : 득점
# * HIT : 안타
# * H2 : 2루타
# * H3 : 3루타
# * HR : 홈런
# * SB : 도루
# * CS : 도루실패
# * SH : 희타(희생타)
# * SF : 희비(희생플라이)
# * BB : 4구
# * IB : 고4(고의 4구)
# * HP : 사구
# * KK : 삼진
# * GD : 병살타
# * ERR : 실책
# * LOB : 잔루 : 이닝이 끝난 상황에 누상에 남아있는 주자 수
# * P_HRA_RT : 득점권타율
# * P_AB_CN : 득점권타수
# * P_HIT_CN : 득점권안타

# %%
LG
# Out:
#               G_ID   GDAY_DS T_ID VS_T_ID  ...  LOB  P_HRA_RT  P_AB_CN  P_HIT_CN
# 1    20160401HHLG0  20160401   LG      HH  ...    8  0.333333       12         4
# 10   20160402HHLG0  20160402   LG      HH  ...   11  0.300000       10         3
# 25   20160405LGHT0  20160405   LG      HT  ...    7  0.200000        5         1
# 43   20160407LGHT0  20160407   LG      HT  ...    8  0.333333       12         4
# 57   20160408LGSK0  20160408   LG      SK  ...    4  0.200000        5         1
# ..             ...       ...  ...     ...  ...  ...       ...      ...       ...
# 693  20210630KTLG0  20210630   LG      KT  ...    0  1.000000        1         1
# 703  20210701KTLG0  20210701   LG      KT  ...    8  0.200000        5         1
# 712  20210702HHLG0  20210702   LG      HH  ...    5  0.142857        7         1
# 723  20210704HHLG0  20210704   LG      HH  ...    6  0.428571        7         3
# 733  20210705HHLG0  20210705   LG      HH  ...   13  0.250000        8         2
#
# ...

# %%
cd 개인타자
# Out:
# [Errno 2] No such file or directory: '개인타자'
# /content/drive/Othercomputers/내 노트북/googleDrive/BigContest/Rookie_League/01_제공데이터/팀타자

# %%
df2_2021 = pd.read_csv('2021 빅콘테스트_데이터분석분야_루키리그_개인타자_2021.csv')
# Out:
# '2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2016.csv'
# '2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2017.csv'
# '2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2018.csv'
# '2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2019.csv'
# '2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2020.csv'
# '2021 빅콘테스트_데이터분석분야_루키리그_팀타자_2021.csv'

# %%
df2_2021.head()

# %% [markdown]
# ### 팀타자와 개인타자 feature 비교

# %%
len(df_2021.columns)

# %%
len(df2_2021.columns)   # 개인 타자가 팀 타자보다 feature가 3개더 많음9
